# %% [markdown]
# Base64 decoder

# %%
import base64
enc_b64 = 'INSERT PUZZLE HERE'

def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	Caesar

# %%
puzzle = 'INSERT PUZZLE'
print("The length of the puzzle is:\t", len(puzzle))

# the length is a multiple of 4, and the alphabet seems too regular (no punctuation).
#we can think that this is a base64 encoded string
puzzle_dec = base64tostring(puzzle)
print("Decoded puzzle:", puzzle_dec)
# Out:
# The length of the puzzle is:	 36
# Decoded puzzle: }{[l^KlwOmwZjmOKW9

# %% [markdown]
# Ceaser Cipher Decoder

# %%
def ceasar_cracker(text, from_ = -30, to_=+30):
    for i in range(from_, to_): #possible keys [-30, 30]
        #decode
        curr_step = ''.join([chr(ord(c) + i) for c in text])

        #print
        print(f"Step={i}\t{curr_step}")

ceasar_cracker(puzzle_dec)
# Out:
# Step=-30	_]=N@-NY1OY<LO1-9
# Step=-29	`^>OA.OZ2PZ=MP2.:
# Step=-28	a_?PB/P[3Q[>NQ3/;
# Step=-27	b`@QC0Q\4R\?OR40<
# Step=-26	caARD1R]5S]@PS51=
# Step=-25	dbBSE2S^6T^AQT62>
# Step=-24	ecCTF3T_7U_BRU73?!
# Step=-23	fdDUG4U`8V`CSV84@"
# Step=-22	geEVH5Va9WaDTW95A#
# Step=-21	hfFWI6Wb:XbEUX:6B$
# Step=-20	igGXJ7Xc;YcFVY;7C%
# Step=-19	jhHYK8Yd<ZdGWZ<8D&
# Step=-18	kiIZL9Ze=[eHX[=9E'
# Step=-17	ljJ[M:[f>\fIY\>:F(
# Step=-16	mkK\N;\g?]gJZ]?;G)
# Step=-15	nlL]O<]h@^hK[^@<H*
# Step=-14	omM^P=^iA_iL\_A=I+
# Step=-13	pnN_Q>_jB`jM]`B>J,
# Step=-12	qoO`R?`kCakN^aC?K-
# Step=-11	rpPaS@alDblO_bD@L.
# Step=-10	sqQbTAbmEcmP`cEAM/
# Step=-9	trRcUBcnFdnQadFBN0
# Step=-8	usSdVCdoGeoRbeGCO1
# Step=-7	vtTeWDepHfpScfHDP2
# Step=-6	wuUfXEfqIgqTdgIEQ3
# Step=-5	xvVgYFgrJhrUehJFR4
# Step=-4	ywWhZGhsKisVfiKGS5
# Step=-3	zxXi[HitLjtWgjLHT6
# Step=-2	{yYj\IjuMkuXhkMIU7
# Step=-1	|zZk]JkvNlvYilNJV8
# Step=0	}{[l^KlwOmwZjmOKW9
# Step=1	~|\m_LmxPnx[knPLX:
# Step=2	}]n`MnyQoy\loQMY;
# Step=3	~^oaNozRpz]mpRNZ<
# Step=4	_pbOp{Sq{^nqSO[=
# Step=5	`qcPq|Tr|_orTP\>
# Step=6	ardQr}Us}`psUQ]?
# Step=7	bseRs~Vt~aqtVR^@
# Step=8	ctfStWubruWS_A
# Step=9	dugTuXvcsvXT`B
# Step=10	evhUvYwdtwYUaC
# Step=11	fwiVwZxeuxZVbD
# Step=12	gxjWx[yfvy[WcE
# Step=13	hykXy\zgwz\XdF
# Step=14	izlYz]{hx{]YeG
# Step=15	j{mZ{^|iy|^ZfH
# Step=16	k|n[|_}jz}_[gI
# Step=17	l}o\}`~k{~`\hJ
# Step=18	m~p]~al|a]iK
# Step=19	nq^bm}b^jL
# Step=20	or_cn~c_kM
# Step=21	ps`dod`lN
# Step=22	qtaepeamO
# Step=23	rubfqfbnP
# Step=24	svcgrgcoQ
# Step=25	twdhshdpR
# Step=26	uxeitieqS
# Step=27	vyfjujfrT
# Step=28	wzgkvkgsU
# Step=29	x{hlwlhtV
