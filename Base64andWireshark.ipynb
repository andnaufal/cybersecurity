# %% [markdown]
# Caasi Vosima organized a party last night to show is new high-tech house to his friends yet
# something went wrong with the multimedia player and the music was turned off.
# It took some time to restart the music player and the party was like frozen for a moment. Caasi
# was able to recover some information collected just before the crash.
# Help Caasi to find out what happened !

# %% [markdown]
# We have a file containing the traffic before the multimedia player crashed. We can order the
# packages based on their length, and we can find that a package has a length equal to ~4K. If
# we look to the content, we see a clear base64 message.

# %% [markdown]
# If you are here, you found a base64 and you decode it … but nothing. Maybe it is still encoded!

# %% [markdown]
# Caasi Vosima organized a party last night to show is new high-tech house to his friends yet
# something went wrong with the multimedia player and the music was turned off.
# It took some time to restart the music player and the party was like frozen for a moment. Caasi
# was able to recover some information collected just before the crash.
# Help Caasi to find out what happened !
# We have a file containing the traffic before the multimedia player crashed. We can order the
# packages based on their length, and we can find that a package has a length equal to ~4K. If
# we look to the content, we see a clear base64 message:
# Vmxkd1NrNVhVbk5qUlZKU1ltdGFjRlJYZEhOaWJFNVhWR3RPV0dKVmJEWldiR1JyV1ZkS1Z
# XRXphRnBpVkVaVFYycEtVMU5IUmtobFJYQlRUVmhDTmxZeFdtdGhhelZ5WWtWYWFWSlVi
# RmRVVlZaYVRURmFjbFpyT1ZaV2JXUTJWa1pvYTFkck1YVlVhbHBoVWxack1GUlZaRXRqVm
# xaMVZHMTRXRkpVUlRCWFdIQkdUbGRHY2s1VmFFOVdNWEJoV1Zkek1XSldaSFJPVm1Scl
# ZsZDRXbFJWVm5wUVVUMDk=
# We can decode it from base64 ... but nothing. However, if you look carefully, the message is
# again a base64 encoding, so we might try to decode it again ... and we still have a base64. We
# can decode the message several times, and after a while the flag is reached!
# Good job ! You found the flag: INSA{TCP_s0ck3t_4n4lys1s_c4n_b3_fun!}

# %%
import base64
enc_b64 = 'Vmxkd1NrNVhVbk5qUlZKU1ltdGFjRlJYZEhOaWJFNVhWR3RPV0dKVmJEWldiR1JyV1ZkS1Z XRXphRnBpVkVaVFYycEtVMU5IUmtobFJYQlRUVmhDTmxZeFdtdGhhelZ5WWtWYWFWSlVi RmRVVlZaYVRURmFjbFpyT1ZaV2JXUTJWa1pvYTFkck1YVlVhbHBoVWxack1GUlZaRXRqVm xaMVZHMTRXRkpVUlRCWFdIQkdUbGRHY2s1VmFFOVdNWEJoV1Zkek1XSldaSFJPVm1Scl ZsZDRXbFJWVm5wUVVUMDk='

def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	VldwSk5XUnNjRVJSYmtacFRXdHNibE5XVGtOWGJVbDZWbGRrWVdKVWEzaFpiVEZTV2pKU1NHRkhlRXBTTVhCNlYxWmthazVyYkVaaVJUbFdUVVZaTTFaclZrOVZWbWQ2VkZoa1drMXVUalphUlZrMFRVZEtjVlZ1VG14WFJURTBXWHBGTldGck5VaE9WMXBhWVdzMWJWZHROVmRrVld4WlRVVnpQUT09

# %%
import base64
enc_b64 = 'VldwSk5XUnNjRVJSYmtacFRXdHNibE5XVGtOWGJVbDZWbGRrWVdKVWEzaFpiVEZTV2pKU1NHRkhlRXBTTVhCNlYxWmthazVyYkVaaVJUbFdUVVZaTTFaclZrOVZWbWQ2VkZoa1drMXVUalphUlZrMFRVZEtjVlZ1VG14WFJURTBXWHBGTldGck5VaE9WMXBhWVdzMWJWZHROVmRrVld4WlRVVnpQUT09'

def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	VWpJNWRscERRbkZpTWtsblNWTkNXbUl6VldkYWJUa3hZbTFSWjJSSGFHeEpSMXB6V1Zkak5rbEZiRTlWTUVZM1ZrVk9VVmd6VFhkWk1uTjZaRVk0TUdKcVVuTmxXRTE0WXpFNWFrNUhOV1paYWs1bVdtNVdkVWxZTUVzPQ==

# %%
import base64
enc_b64 = 'VldwSk5XUnNjRVJSYmtacFRXdHNibE5XVGtOWGJVbDZWbGRrWVdKVWEzaFpiVEZTV2pKU1NHRkhlRXBTTVhCNlYxWmthazVyYkVaaVJUbFdUVVZaTTFaclZrOVZWbWQ2VkZoa1drMXVUalphUlZrMFRVZEtjVlZ1VG14WFJURTBXWHBGTldGck5VaE9WMXBhWVdzMWJWZHROVmRrVld4WlRVVnpQUT09'

def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	VWpJNWRscERRbkZpTWtsblNWTkNXbUl6VldkYWJUa3hZbTFSWjJSSGFHeEpSMXB6V1Zkak5rbEZiRTlWTUVZM1ZrVk9VVmd6VFhkWk1uTjZaRVk0TUdKcVVuTmxXRTE0WXpFNWFrNUhOV1paYWs1bVdtNVdkVWxZTUVzPQ==

# %%
import base64
enc_b64 = 'VWpJNWRscERRbkZpTWtsblNWTkNXbUl6VldkYWJUa3hZbTFSWjJSSGFHeEpSMXB6V1Zkak5rbEZiRTlWTUVZM1ZrVk9VVmd6VFhkWk1uTjZaRVk0TUdKcVVuTmxXRTE0WXpFNWFrNUhOV1paYWs1bVdtNVdkVWxZTUVzPQ=='
def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	UjI5dlpDQnFiMklnSVNCWmIzVWdabTkxYm1RZ2RHaGxJR1pzWVdjNklFbE9VMEY3VkVOUVgzTXdZMnN6ZEY4MGJqUnNlWE14YzE5ak5HNWZZak5mWm5WdUlYMEs=

# %%
import base64
enc_b64 = 'UjI5dlpDQnFiMklnSVNCWmIzVWdabTkxYm1RZ2RHaGxJR1pzWVdjNklFbE9VMEY3VkVOUVgzTXdZMnN6ZEY4MGJqUnNlWE14YzE5ak5HNWZZak5mWm5WdUlYMEs='
def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	R29vZCBqb2IgISBZb3UgZm91bmQgdGhlIGZsYWc6IElOU0F7VENQX3MwY2szdF80bjRseXMxc19jNG5fYjNfZnVuIX0K

# %%
import base64
enc_b64 = 'R29vZCBqb2IgISBZb3UgZm91bmQgdGhlIGZsYWc6IElOU0F7VENQX3MwY2szdF80bjRseXMxc19jNG5fYjNfZnVuIX0K'
def base64tostring(text):
    return base64.b64decode(text).decode('utf-8', errors="ignore")

print(f"Decoding=\t{base64tostring(enc_b64)}")
# Out:
# Decoding=	Good job ! You found the flag: INSA{TCP_s0ck3t_4n4lys1s_c4n_b3_fun!}
